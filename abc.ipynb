# %%
pip install -q transformers accelerate bitsandbytes sentencepiece
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -q gradio transformers torch sentence-transformers faiss-cpu peft bitsandbytes
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -U bitsandbytes accelerate transformers peft
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -------------- ------------------------- 4.2/11.6 MB 21.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 38.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 77.8 MB/s eta 0:00:00
# ...
#
#   Attempting uninstall: tokenizers
#
#     Found existing installation: tokenizers 0.21.2
#
#     Uninstalling tokenizers-0.21.2:
#
#       Successfully uninstalled tokenizers-0.21.2
#
#    ---------------------------------------- 0/3 [tokenizers]
#   Attempting uninstall: accelerate
#    ---------------------------------------- 0/3 [tokenizers]
#     Found existing installation: accelerate 1.10.0
#    ---------------------------------------- 0/3 [tokenizers]
#    ------------- -------------------------- 1/3 [accelerate]
#     Uninstalling accelerate-1.10.0:
# ...

# %%
import os

print(os.getcwd())  # In ra thư mục hiện tại
# Out:
# c:\Users\Admin\OneDrive - Hanoi University of Science and Technology\Desktop\MusicChatbot

# %%
cd MusicChatbot/model/llama/
# Out:
# c:\Users\Admin\OneDrive - Hanoi University of Science and Technology\Desktop\MusicChatbot\model\llama

# %%
from pipelinee import PipelineConfig
from model.llama.gradioo import MusicChatbotGUI

# Quick launch
config = PipelineConfig(
    songs_db_path="scripts/crawl/songs.json",
    use_rag=True,
    temperature=0.7
)

gui = MusicChatbotGUI(config)
demo = gui.create_interface()
demo.launch(share=True)  # Tạo public URL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from pipelinee import PipelineConfig
#       2 from model.llama.gradioo import MusicChatbotGUI
#       4 # Quick launch
#
# File c:\Users\Admin\OneDrive - Hanoi University of Science and Technology\Desktop\MusicChatbot\model\llama\pipelinee.py:8
#       5 import torch
#       7 from conversation import ConversationManager
# ----> 8 from rag import RAGRetriever
# ...
